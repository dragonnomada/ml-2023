# %% [markdown]
# # Caso de Estudio - Proyectos Finalizados
#
# Tenemos una base de datos en Excel la cual contiene muestras de proyectos con columnas como eficiencia y esfuerzo.
#
# Vamos a integrar los datos a análisis de afinidad, clasificación y algunas técnicas para limpieza de datos si hiciera falta.

# %% [markdown]
# ## 1. Cargar los datos del Excel
#
# Nota: El archivo `ProyectosFinalizados.xlsx` debe estar disponible de una forma práctica en la computadora o cargado al Colab.

# %% [markdown]
# Instalamos la librería `openpyxl` para poder cargar el archivo de excel

# %%
import numpy as np
! pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in d:\conda\envs\deep-learning\lib\site-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in d:\conda\envs\deep-learning\lib\site-packages (from openpyxl) (1.1.0)

# %%
import pandas as pd

proyectos = pd.read_excel("data/ProyectosFinalizados.xlsx", sheet_name="base")

proyectos.head()
# Out:
#    IDProyecto Empresa  Peticion  Peticion.1  pet+empresa
# 0           1  México    8318.0        8318   8318México  \
# 1           2  México    9619.0        9619   9619México
# 2           3  México   10438.0       10438  10438México
# 3           4  México   10522.0       10522  10522México
# 4           5  México   10528.0       10528  10528México
#
#                                               Nombre  Cfp  Eficiencia
# 0  Modificación a la utileria de generación de pa...   12         NaN  \
# 1              Modificacion al programa Vbncarga.exe    2         NaN
# 2  Permisos para Cambios de puntos de Sembrado- P...   11         NaN
# 3             Corrección del informe TabuladoCredito   11         NaN
# 4  Corrección al Tabulado de Carteras y Hojas men...    4         NaN
#
#           PDR  EsfuerzoTotalP  ...  PDR S  PDR M1  PDR M2 PDR L Lead Time
# 0   33.708333           404.5  ...    NaN     NaN     NaN   NaN     914.0  \
# 1  147.500000           295.0  ...    NaN     NaN     NaN   NaN     609.0
# 2   51.375455          1019.0  ...    NaN     NaN     NaN   NaN     519.0
# 3   47.727273           525.0  ...    NaN     NaN     NaN   NaN     493.0
# 4   26.290000           213.0  ...    NaN     NaN     NaN   NaN     557.0
#
#    F1GestiondelaDemanda F2Elicitacion F3Contruccion  F4Final  Tamaño
# 0                 825.0           8.0          42.0     35.0   10-29
# 1                 584.0           7.0          14.0      1.0     2-9
# 2                 461.0           2.0          37.0      1.0   10-29
# 3                 455.0           9.0          27.0      1.0   10-29
# 4                 520.0           5.0          30.0      0.0     2-9
#
# [5 rows x 138 columns]

# %% [markdown]
# ## 2. Reestructuramos las columnas para que sean fáciles de consumir

# %%
print(list(proyectos.columns.values))
# Out:
# ['IDProyecto', 'Empresa', 'Peticion', 'Peticion.1', 'pet+empresa', 'Nombre', 'Cfp', 'Eficiencia', 'PDR', 'EsfuerzoTotalP', 'EsfuerzoTotalR', 'EsfuerzoTotalE', 'EsfuerzoTotalV', 'EsfPlaneacionP', 'EsfPlaneacionR', 'EsfPlaneacionV', 'EsfElicitacionP', 'EsfElicitacionR', 'EsfElicitacionE', 'EsfElicitacionV', 'EsfDocumentacionP', 'EsfDocumentacionR', 'EsfDocumentacionE', 'EsfDocumentacionV', 'EsfArquitecturaP', 'EsfArquitecturaR', 'EsfArquitecturaE', 'EsfArquitecturaV', 'EsfCodificacionP', 'EsfCodificacionR', 'EsfCodificacionE', 'EsfCodificacionV', 'EsfPruebasP', 'EsfPruebasR', 'EsfPruebasE', 'EsfPruebasV', 'EsfImplementacionP', 'EsfImplementacionR', 'EsfImplementacionV', 'EsfOtrosP', 'EsfOtrosR', 'EsfOtrosV', 'ArquitecturaI', 'LenguajeI', 'BDI', 'FrameworkI', 'ArquitecturaV', 'LenguajeV', 'BDV', 'FrameworkV', 'EstDuracion', 'DiasLaborales', 'DiasNaturales', 'FechaMedicion', 'Creacion', 'PorAutorizarIniciativa(Primera)', 'PorAutorizarIniciativa(Ultima)', 'PorAutorizarEvaluadorProyectos(Primera)', 'PorAutorizarEvaluadorProyectos(Ultima)', 'PorAutorizarGerenteProyectos(Primera)', 'PorAutorizarGerenteProyectos(Ultima)', 'AutorizadaEnEsperaPrioridad(Primera)', 'AutorizadaEnEsperaPrioridad(Ultima)', 'Analisis(Primera)', 'Analisis(Ultima)', 'EsperaAutorizacionContrato(Primera)', 'EsperaAutorizacionContrato(Ultima)', 'EsperaDeFechaPromesa(Primera)', 'EsperaDeFechaPromesa(Ultima)', 'EnDesarrollo(Primera)', 'EnDesarrollo(Ultima)', 'ValidarEntregable(Primera)', 'ValidarEntregable(Ultima)', 'PorInstalar', 'Finalizo', 'Detenida', 'Medidor', 'Lider', 'Analista1', 'Analista2', 'Analista3', 'Analista4', 'Arquitecto1', 'Arquitecto2', 'Arquitecto3', 'Arquitecto4', 'Programador1', 'Programador2', 'Programador3', 'Programador4', 'Programador5', 'Tester1', 'Tester2', 'Tester3', 'Tester4', 'Dirección', 'Director', 'Division', 'Divisional', 'Dirección Servicios Financieros', 'Director Servicios Financieros', 'Gerencia Nacional', 'Gerente Nacional', 'Coordinación', 'Coordinador', 'Centro líder', 'Coordinador Centro Desarrollo APS', 'Coordinacion Centro Desarrollo APS', 'NombreCentro Desarrollo', 'Metodologia', 'AprobadoModelos', 'AprobadoModelosEsfuerzo', 'AprobadoModelosDuración', 'InfoValidada', 'Proveedor', 'Normativo', 'SigueProceso', 'RNF', 'TipoDesarrollo', 'VersionProceso', 'Observaciones', 'Anotaciones', 'ComentatioProductividad', 'FechaFestivo', 'NombreFestivo', 'PDR Limpio', 'PDR XXS', 'PDR XS', 'PDR S', 'PDR M1', 'PDR M2', 'PDR L', 'Lead Time', 'F1GestiondelaDemanda', 'F2Elicitacion', 'F3Contruccion', 'F4Final', 'Tamaño']

# %%
def limpiar_columna(columna):
    # 1. Reemplazar caracteres especiales
    columna = columna.replace(" ", "_") \
        .replace("á", "a") \
        .replace("é", "e") \
        .replace("í", "i") \
        .replace("ó", "o") \
        .replace("ú", "u") \
        .replace("ñ", "n") \
        .replace("+", "_") \
        .replace(".", "_") \
        .replace("(", "_") \
        .replace(")", "")
    import re
    # 2. Poner un guion bajo entre cambio de letras de minúscula a mayúsculas
    columna = re.sub("([a-z])([A-Z])", "\\1_\\2", columna)
    # 3. Poner un guion bajo entre ID y letra
    columna = re.sub("ID([A-Za-z])", "ID_\\1", columna)
    # 4. Poner un guion bajo entre número y letra
    columna = re.sub("([0-9])([A-Za-z])", "\\1_\\2", columna)
    # 4. Poner un guion bajo entre letra y número
    columna = re.sub("([A-Za-z])([0-9])", "\\1_\\2", columna)
    # 5. Quitar un guion bajo entre letra y número
    columna = re.sub("([A-Za-z])_([0-9])", "\\1\\2", columna)
    # 6. Poner un guion bajo entre letra y número final
    columna = re.sub("([A-Za-z])([0-9])$", "\\1_\\2", columna)
    # 7. Convertir a mayúsculas
    columna = columna.upper()
    return columna

proyectos.columns = map(limpiar_columna, proyectos.columns.values)

proyectos.head()
# Out:
#    ID_PROYECTO EMPRESA  PETICION  PETICION_1  PET_EMPRESA
# 0            1  México    8318.0        8318   8318México  \
# 1            2  México    9619.0        9619   9619México
# 2            3  México   10438.0       10438  10438México
# 3            4  México   10522.0       10522  10522México
# 4            5  México   10528.0       10528  10528México
#
#                                               NOMBRE  CFP  EFICIENCIA
# 0  Modificación a la utileria de generación de pa...   12         NaN  \
# 1              Modificacion al programa Vbncarga.exe    2         NaN
# 2  Permisos para Cambios de puntos de Sembrado- P...   11         NaN
# 3             Corrección del informe TabuladoCredito   11         NaN
# 4  Corrección al Tabulado de Carteras y Hojas men...    4         NaN
#
#           PDR  ESFUERZO_TOTAL_P  ...  PDR_S  PDR_M_1  PDR_M_2 PDR_L LEAD_TIME
# 0   33.708333             404.5  ...    NaN      NaN      NaN   NaN     914.0  \
# 1  147.500000             295.0  ...    NaN      NaN      NaN   NaN     609.0
# 2   51.375455            1019.0  ...    NaN      NaN      NaN   NaN     519.0
# 3   47.727273             525.0  ...    NaN      NaN      NaN   NaN     493.0
# 4   26.290000             213.0  ...    NaN      NaN      NaN   NaN     557.0
#
#    F1_GESTIONDELA_DEMANDA F2_ELICITACION F3_CONTRUCCION  F4_FINAL  TAMANO
# 0                   825.0            8.0           42.0      35.0   10-29
# 1                   584.0            7.0           14.0       1.0     2-9
# 2                   461.0            2.0           37.0       1.0   10-29
# 3                   455.0            9.0           27.0       1.0   10-29
# 4                   520.0            5.0           30.0       0.0     2-9
#
# [5 rows x 138 columns]

# %%
print(list(proyectos.columns.values))
# Out:
# ['ID_PROYECTO', 'EMPRESA', 'PETICION', 'PETICION_1', 'PET_EMPRESA', 'NOMBRE', 'CFP', 'EFICIENCIA', 'PDR', 'ESFUERZO_TOTAL_P', 'ESFUERZO_TOTAL_R', 'ESFUERZO_TOTAL_E', 'ESFUERZO_TOTAL_V', 'ESF_PLANEACION_P', 'ESF_PLANEACION_R', 'ESF_PLANEACION_V', 'ESF_ELICITACION_P', 'ESF_ELICITACION_R', 'ESF_ELICITACION_E', 'ESF_ELICITACION_V', 'ESF_DOCUMENTACION_P', 'ESF_DOCUMENTACION_R', 'ESF_DOCUMENTACION_E', 'ESF_DOCUMENTACION_V', 'ESF_ARQUITECTURA_P', 'ESF_ARQUITECTURA_R', 'ESF_ARQUITECTURA_E', 'ESF_ARQUITECTURA_V', 'ESF_CODIFICACION_P', 'ESF_CODIFICACION_R', 'ESF_CODIFICACION_E', 'ESF_CODIFICACION_V', 'ESF_PRUEBAS_P', 'ESF_PRUEBAS_R', 'ESF_PRUEBAS_E', 'ESF_PRUEBAS_V', 'ESF_IMPLEMENTACION_P', 'ESF_IMPLEMENTACION_R', 'ESF_IMPLEMENTACION_V', 'ESF_OTROS_P', 'ESF_OTROS_R', 'ESF_OTROS_V', 'ARQUITECTURA_I', 'LENGUAJE_I', 'BDI', 'FRAMEWORK_I', 'ARQUITECTURA_V', 'LENGUAJE_V', 'BDV', 'FRAMEWORK_V', 'EST_DURACION', 'DIAS_LABORALES', 'DIAS_NATURALES', 'FECHA_MEDICION', 'CREACION', 'POR_AUTORIZAR_INICIATIVA_PRIMERA', 'POR_AUTORIZAR_INICIATIVA_ULTIMA', 'POR_AUTORIZAR_EVALUADOR_PROYECTOS_PRIMERA', 'POR_AUTORIZAR_EVALUADOR_PROYECTOS_ULTIMA', 'POR_AUTORIZAR_GERENTE_PROYECTOS_PRIMERA', 'POR_AUTORIZAR_GERENTE_PROYECTOS_ULTIMA', 'AUTORIZADA_EN_ESPERA_PRIORIDAD_PRIMERA', 'AUTORIZADA_EN_ESPERA_PRIORIDAD_ULTIMA', 'ANALISIS_PRIMERA', 'ANALISIS_ULTIMA', 'ESPERA_AUTORIZACION_CONTRATO_PRIMERA', 'ESPERA_AUTORIZACION_CONTRATO_ULTIMA', 'ESPERA_DE_FECHA_PROMESA_PRIMERA', 'ESPERA_DE_FECHA_PROMESA_ULTIMA', 'EN_DESARROLLO_PRIMERA', 'EN_DESARROLLO_ULTIMA', 'VALIDAR_ENTREGABLE_PRIMERA', 'VALIDAR_ENTREGABLE_ULTIMA', 'POR_INSTALAR', 'FINALIZO', 'DETENIDA', 'MEDIDOR', 'LIDER', 'ANALISTA_1', 'ANALISTA_2', 'ANALISTA_3', 'ANALISTA_4', 'ARQUITECTO_1', 'ARQUITECTO_2', 'ARQUITECTO_3', 'ARQUITECTO_4', 'PROGRAMADOR_1', 'PROGRAMADOR_2', 'PROGRAMADOR_3', 'PROGRAMADOR_4', 'PROGRAMADOR_5', 'TESTER_1', 'TESTER_2', 'TESTER_3', 'TESTER_4', 'DIRECCION', 'DIRECTOR', 'DIVISION', 'DIVISIONAL', 'DIRECCION_SERVICIOS_FINANCIEROS', 'DIRECTOR_SERVICIOS_FINANCIEROS', 'GERENCIA_NACIONAL', 'GERENTE_NACIONAL', 'COORDINACION', 'COORDINADOR', 'CENTRO_LIDER', 'COORDINADOR_CENTRO_DESARROLLO_APS', 'COORDINACION_CENTRO_DESARROLLO_APS', 'NOMBRE_CENTRO_DESARROLLO', 'METODOLOGIA', 'APROBADO_MODELOS', 'APROBADO_MODELOS_ESFUERZO', 'APROBADO_MODELOS_DURACION', 'INFO_VALIDADA', 'PROVEEDOR', 'NORMATIVO', 'SIGUE_PROCESO', 'RNF', 'TIPO_DESARROLLO', 'VERSION_PROCESO', 'OBSERVACIONES', 'ANOTACIONES', 'COMENTATIO_PRODUCTIVIDAD', 'FECHA_FESTIVO', 'NOMBRE_FESTIVO', 'PDR_LIMPIO', 'PDR_XXS', 'PDR_XS', 'PDR_S', 'PDR_M_1', 'PDR_M_2', 'PDR_L', 'LEAD_TIME', 'F1_GESTIONDELA_DEMANDA', 'F2_ELICITACION', 'F3_CONTRUCCION', 'F4_FINAL', 'TAMANO']

# %% [markdown]
# ## 3. Inspeccionar el dataset

# %%
proyectos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2955 entries, 0 to 2954
# Columns: 138 entries, ID_PROYECTO to TAMANO
# dtypes: datetime64[ns](24), float64(42), int64(6), object(66)
# memory usage: 3.1+ MB

# %%
proyectos.describe()
# Out:
#        ID_PROYECTO      PETICION    PETICION_1          CFP   EFICIENCIA
# count  2955.000000   2955.000000   2955.000000  2955.000000  1514.000000  \
# mean   1478.000000  11504.667783  11504.575635    44.551946     0.817883
# min       1.000000     21.100000     21.000000     0.000000     0.058973
# 25%     739.500000    756.100000    756.000000     5.000000     0.478629
# 50%    1478.000000  12306.000000  12306.000000    15.000000     0.758016
# 75%    2216.500000  19945.600000  19945.500000    46.000000     1.241265
# max    2955.000000  37966.100000  37966.000000  2450.000000     1.400000
# std     853.179348  10478.873288  10478.865454   103.826405     0.405586
#
#                PDR  ESFUERZO_TOTAL_P  ESFUERZO_TOTAL_R  ESFUERZO_TOTAL_E
# count  2765.000000       2955.000000       2955.000000       2955.000000  \
# mean     49.728474       1251.967462       1282.559263        371.355868
# min       0.000000          0.000000          0.000000          0.000000
# 25%       3.083947        275.000000        220.170000          0.000000
# 50%      24.315000        638.500000        586.470000        125.000000
# 75%      56.857500       1465.250000       1407.280000        375.500000
# max    2715.690000      27413.500000      48150.580000      17010.000000
# std      97.581442       1899.602525       2424.241745        848.577096
#
#        ESFUERZO_TOTAL_V  ...      PDR_XS       PDR_S     PDR_M_1    PDR_M_2
# count       2955.000000  ...  552.000000  508.000000  171.000000  25.000000  \
# mean         755.950364  ...   40.774953   28.351650   18.920621  11.668764
# min            0.000000  ...    3.650000    2.842121    1.449783   1.151212
# 25%            0.000000  ...   20.845625   13.236971    9.925193   6.699141
# 50%          310.580000  ...   32.941973   22.493103   16.493254   9.087537
# 75%          908.370000  ...   53.679714   36.002445   22.832040  14.656096
# max        18365.000000  ...  131.230769  130.839737   72.365534  33.374603
# std         1281.481372  ...   27.683001   21.231442   12.731515   8.350171
#
#           PDR_L    LEAD_TIME  F1_GESTIONDELA_DEMANDA  F2_ELICITACION
# count  2.000000  2818.000000             2812.000000     2812.000000  \
# mean   7.073779   310.930092              153.293385       50.853485
# min    6.651639     3.000000                0.000000        0.000000
# 25%    6.862709    92.000000               14.000000        7.000000
# 50%    7.073779   192.000000               49.500000       15.000000
# 75%    7.284849   403.250000              170.250000       38.000000
# max    7.495918  3008.000000             2192.000000     1350.000000
# std    0.596995   341.690203              266.345435      110.039897
#
#        F3_CONTRUCCION     F4_FINAL
# count     2811.000000  2818.000000
# mean        94.662753    18.540099
# min          0.000000     0.000000
# 25%         25.000000     0.000000
# 50%         55.000000     3.000000
# 75%        119.000000    14.000000
# max       1365.000000   764.000000
# std        118.756275    52.195470
#
# [8 rows x 72 columns]

# %%
num_samples = 3 # Selecciona 3 muestras aleatorias
num_cols = 4    # Muestra de 4 en 4 columnas de las muestras

max_cols = len(proyectos.T) # Calcula el total de columnas

samples = proyectos.sample(num_samples) # Selecciona el número de muestras

# Recorre de 4 en 4 columnas
for i in range(0, max_cols, num_cols):
    # Imprime las columnas que se están visualizando
    print("Columnas del {} al {}".format(i + 1, min(i + num_cols, max_cols)))
    # Imprime los valores en el dataset de las muestras en esas columnas
    print(samples.T[i:i+num_cols].T)
# Out:
# Columnas del 1 al 4
#      ID_PROYECTO    EMPRESA PETICION PETICION_1
# 2500        2501  Argentina    495.1        495
# 426          427  Bancoppel    101.0        101
# 1046        1047     México  18820.1      18820
# Columnas del 5 al 8
#        PET_EMPRESA                                             NOMBRE  CFP
# 2500  495Argentina                  Actualización de proceso en el CT   31  \
# 426   101Bancoppel  101-RQI 03 523 Desglose de Importe Total en Tr...    2
# 1046   18820México                MEJORAS SISTEMA RETROTRAIDO MUEBLES  181
#
#      EFICIENCIA
# 2500   0.322096
# 426         NaN
# 1046        NaN
# Columnas del 9 al 12
#             PDR ESFUERZO_TOTAL_P ESFUERZO_TOTAL_R ESFUERZO_TOTAL_E
# 2500        0.0           2194.5          1889.34              0.0
# 426       92.23            251.0           234.57              0.0
# 1046  15.386906           3252.0          1800.42           1375.0
# Columnas del 13 al 16
#      ESFUERZO_TOTAL_V ESF_PLANEACION_P ESF_PLANEACION_R ESF_PLANEACION_V
# 2500              0.0            551.5           513.27              0.0
# 426            184.46             81.5            77.78            42.28
# 1046          2785.03              742           651.23           651.23
# Columnas del 17 al 20
#      ESF_ELICITACION_P ESF_ELICITACION_R ESF_ELICITACION_E ESF_ELICITACION_V
# 2500               117            124.09               0.0               0.0
# 426                 22             10.47               0.0             10.47
# 1046               234            121.13             175.0             234.0
# Columnas del 21 al 24
#      ESF_DOCUMENTACION_P ESF_DOCUMENTACION_R ESF_DOCUMENTACION_E
# 2500                  91               82.91                 0.0  \
# 426                 22.5               25.45                 0.0
# 1046                99.5               85.29                 0.0
#
#      ESF_DOCUMENTACION_V
# 2500                 0.0
# 426                21.17
# 1046               85.29
# Columnas del 25 al 28
#      ESF_ARQUITECTURA_P ESF_ARQUITECTURA_R ESF_ARQUITECTURA_E
# 2500                392             223.29                  0  \
# 426                48.5              56.43                  0
# 1046                711             353.03                  0
#
#      ESF_ARQUITECTURA_V
# 2500                0.0
# 426               56.43
# 1046             353.03
# Columnas del 29 al 32
#      ESF_CODIFICACION_P ESF_CODIFICACION_R ESF_CODIFICACION_E
# 2500              431.5             413.11                  0  \
# 426                  10               10.8                  0
# 1046              718.5             221.51                817
#
#      ESF_CODIFICACION_V
# 2500                0.0
# 426                10.8
# 1046              718.5
# Columnas del 33 al 36
#      ESF_PRUEBAS_P ESF_PRUEBAS_R ESF_PRUEBAS_E ESF_PRUEBAS_V
# 2500           562        492.47             0           0.0
# 426           36.5         27.15             0         27.15
# 1046           681        338.59           383         681.0
# Columnas del 37 al 40
#      ESF_IMPLEMENTACION_P ESF_IMPLEMENTACION_R ESF_IMPLEMENTACION_V
# 2500                   10                    0                  0.0  \
# 426                    16                15.62                 1.01
# 1046                   43                10.66                 43.0
#
#      ESF_OTROS_P
# 2500        39.5
# 426         14.0
# 1046        23.0
# Columnas del 41 al 44
#      ESF_OTROS_R ESF_OTROS_V    ARQUITECTURA_I LENGUAJE_I
# 2500        40.2         0.0  Cliente/Servidor        C++
# 426        10.87       15.15               NaN        NaN
# 1046       18.98       18.98  Cliente/Servidor         C#
# Columnas del 45 al 48
#              BDI FRAMEWORK_I    ARQUITECTURA_V  LENGUAJE_V
# 2500  PostgreSQL         NaN               NaN         NaN
# 426          NaN         NaN             Capas  JavaScript
# 1046   SQLServer         NaN  Cliente/Servidor          C#
# Columnas del 49 al 52
#             BDV FRAMEWORK_V EST_DURACION DIAS_LABORALES
# 2500        NaN         NaN            0          109.0
# 426    Informix         NaN            0           10.0
# 1046  SQLServer         NaN            0          143.0
# Columnas del 53 al 56
#      DIAS_NATURALES FECHA_MEDICION   CREACION POR_AUTORIZAR_INICIATIVA_PRIMERA
# 2500          156.0     2018-05-03 2017-07-13                       2017-07-13
# 426            13.0            NaT 2016-07-14                       2016-07-14
# 1046          203.0     2018-10-09 2018-02-28                              NaT
# Columnas del 57 al 60
#      POR_AUTORIZAR_INICIATIVA_ULTIMA
# 2500                      2017-07-13  \
# 426                       2016-07-14
# 1046                             NaT
#
#      POR_AUTORIZAR_EVALUADOR_PROYECTOS_PRIMERA
# 2500                                       NaT  \
# 426                                        NaT
# 1046                                2018-03-07
#
#      POR_AUTORIZAR_EVALUADOR_PROYECTOS_ULTIMA
# 2500                                      NaT  \
# 426                                       NaT
# 1046                               2018-03-07
#
#      POR_AUTORIZAR_GERENTE_PROYECTOS_PRIMERA
# 2500                                     NaT
# 426                                      NaT
# 1046                              2018-03-07
# Columnas del 61 al 64
#      POR_AUTORIZAR_GERENTE_PROYECTOS_ULTIMA
# 2500                                    NaT  \
# 426                                     NaT
# 1046                             2018-03-07
#
#      AUTORIZADA_EN_ESPERA_PRIORIDAD_PRIMERA
# 2500                             2017-07-24  \
# 426                              2016-07-14
# 1046                             2018-06-05
#
#      AUTORIZADA_EN_ESPERA_PRIORIDAD_ULTIMA ANALISIS_PRIMERA
# 2500                            2017-07-24       2018-03-07
# 426                             2016-07-14       2016-07-15
# 1046                            2018-06-05       2018-06-18
# Columnas del 65 al 68
#      ANALISIS_ULTIMA ESPERA_AUTORIZACION_CONTRATO_PRIMERA
# 2500      2018-03-07                           2018-04-11  \
# 426       2016-07-15                           2016-07-20
# 1046      2018-06-18                           2018-08-21
#
#      ESPERA_AUTORIZACION_CONTRATO_ULTIMA ESPERA_DE_FECHA_PROMESA_PRIMERA
# 2500                          2018-04-11                      2018-04-30
# 426                           2016-07-20                      2016-07-21
# 1046                          2018-08-21                      2018-09-28
# Columnas del 69 al 72
#      ESPERA_DE_FECHA_PROMESA_ULTIMA EN_DESARROLLO_PRIMERA
# 2500                     2018-04-30            2018-05-04  \
# 426                      2016-07-21            2016-07-25
# 1046                     2018-09-28            2018-10-03
#
#      EN_DESARROLLO_ULTIMA VALIDAR_ENTREGABLE_PRIMERA
# 2500           2018-05-04                 2018-08-10
# 426            2016-07-25                 2016-07-28
# 1046           2018-10-03                 2019-01-07
# Columnas del 73 al 76
#      VALIDAR_ENTREGABLE_ULTIMA POR_INSTALAR   FINALIZO DETENIDA
# 2500                2018-08-10   2019-02-08 2019-02-19      NaT
# 426                 2016-07-28   2016-08-08 2016-08-08      NaT
# 1046                2019-01-07   2019-01-07 2019-01-07      NaT
# Columnas del 77 al 80
#                                  MEDIDOR                         LIDER
# 2500  PRISMA GUADALUPE CALDERON SANDOVAL  FRANCISCO JAVIER CRUZ YURIAR  \
# 426                                  NaN                           NaN
# 1046          KATIA LIZBETH LEYVA MILLAN    JESUS EDGARDO AMADOR DERAZ
#
#                          ANALISTA_1 ANALISTA_2
# 2500  LUCERO ESTEFANIHE MEZA DIARTE        NaN
# 426                             NaN        NaN
# 1046     JESUS ALVARO URIAS CHAIDEZ        NaN
# Columnas del 81 al 84
#      ANALISTA_3 ANALISTA_4 ARQUITECTO_1 ARQUITECTO_2
# 2500        NaN        NaN          NaN          NaN
# 426         NaN        NaN          NaN          NaN
# 1046        NaN        NaN          NaN          NaN
# Columnas del 85 al 88
#      ARQUITECTO_3 ARQUITECTO_4 PROGRAMADOR_1 PROGRAMADOR_2
# 2500          NaN          NaN           NaN           NaN
# 426           NaN          NaN           NaN           NaN
# 1046          NaN          NaN           NaN           NaN
# Columnas del 89 al 92
#      PROGRAMADOR_3 PROGRAMADOR_4 PROGRAMADOR_5 TESTER_1
# 2500           NaN           NaN           NaN      NaN
# 426            NaN           NaN           NaN      NaN
# 1046           NaN           NaN           NaN      NaN
# Columnas del 93 al 96
#      TESTER_2 TESTER_3 TESTER_4
# 2500      NaN      NaN      NaN  \
# 426       NaN      NaN      NaN
# 1046      NaN      NaN      NaN
#
#                                               DIRECCION
# 2500  DIRECTOR CORPORATIVO DE SISTEMAS CORPORATIVOS ...
# 426                                                 NaN
# 1046  DIRECTOR CORPORATIVO SISTEMAS DE NEGOCIOS Y TR...
# Columnas del 97 al 100
#               DIRECTOR                  DIVISION
# 2500   Antonio Saracho  DIV SOLUCIONES CORPOR TI  \
# 426                NaN                       NaN
# 1046  Santiago Ontañón             DIV RETAIL IT
#
#                           DIVISIONAL DIRECCION_SERVICIOS_FINANCIEROS
# 2500  JUAN ANTONIO PINACHO VELAZQUEZ                             NaN
# 426                              NaN                             NaN
# 1046   DIEGO ALBERTO OSUNA SARMIENTO                             NaN
# Columnas del 101 al 104
#      DIRECTOR_SERVICIOS_FINANCIEROS           GERENCIA_NACIONAL
# 2500                            NaN  SOLUCIONES Y OPS ARGENTINA  \
# 426                             NaN                         NaN
# 1046                            NaN   SIST CADENA DE SUMINISTRO
#
#                 GERENTE_NACIONAL              COORDINACION
# 2500  JULIO CESAR LANDEY ZAMUDIO    COORD DESARROLLO ARG I
# 426                          NaN                       NaN
# 1046             ALFREDO INZUNZA  SIST PROG PROY CORE OPER
# Columnas del 105 al 108
#                   COORDINADOR CENTRO_LIDER COORDINADOR_CENTRO_DESARROLLO_APS
# 2500  JOSE DAVID AGUIRRE DIAZ     230447.0                JULIO CESAR LANDEY  \
# 426                       NaN          NaN           JOSE LUIS BUENO SANCHEZ
# 1046             SERGIO FELIX     230486.0     JOSE ALFREDO INZUNZA GASTELUM
#
#      COORDINACION_CENTRO_DESARROLLO_APS
# 2500                          Argentina
# 426                           Bancoppel
# 1046                                III
# Columnas del 109 al 112
#                      NOMBRE_CENTRO_DESARROLLO METODOLOGIA APROBADO_MODELOS
# 2500      231109 - CLCN DESARROLLO SIST A+B I     Cascada              0.0  \
# 426   230203 - CLCN DESARROLLO SIST BANCO III     Cascada              0.0
# 1046     230486 - CLCN SISTEMAS DESARROLLO XV     Cascada              1.0
#
#      APROBADO_MODELOS_ESFUERZO
# 2500                       0.0
# 426                        0.0
# 1046                       1.0
# Columnas del 113 al 116
#      APROBADO_MODELOS_DURACION INFO_VALIDADA PROVEEDOR NORMATIVO
# 2500                       0.0           1.0       0.0       0.0
# 426                        0.0           1.0       0.0       0.0
# 1046                       1.0           1.0       0.0       0.0
# Columnas del 117 al 120
#      SIGUE_PROCESO  RNF TIPO_DESARROLLO VERSION_PROCESO
# 2500           1.0  NaN          Mejora             6.1
# 426            1.0  NaN          Mejora             4.2
# 1046           1.0  NaN          Mejora             6.1
# Columnas del 121 al 124
#      OBSERVACIONES                                        ANOTACIONES
# 2500           NaN  Proyecto AdmWeb que no aplica para modelos (se...  \
# 426            NaN                                                NaN
# 1046           NaN                                                NaN
#
#      COMENTATIO_PRODUCTIVIDAD FECHA_FESTIVO
# 2500                      NaN           NaT
# 426                       NaN           NaT
# 1046                      NaN           NaT
# Columnas del 125 al 128
#      NOMBRE_FESTIVO PDR_LIMPIO PDR_XXS PDR_XS
# 2500            NaN        NaN     NaN    NaN
# 426             NaN      92.23   92.23    NaN
# 1046            NaN  15.386906     NaN    NaN
# Columnas del 129 al 132
#      PDR_S    PDR_M_1 PDR_M_2 PDR_L
# 2500   NaN        NaN     NaN   NaN
# 426    NaN        NaN     NaN   NaN
# 1046   NaN  15.386906     NaN   NaN
# Columnas del 133 al 136
#      LEAD_TIME F1_GESTIONDELA_DEMANDA F2_ELICITACION F3_CONTRUCCION
# 2500     586.0                  237.0           35.0          284.0
# 426       25.0                    1.0            5.0           18.0
# 1046     313.0                  110.0           64.0          101.0
# Columnas del 137 al 138
#      F4_FINAL   TAMANO
# 2500     11.0    30-99
# 426       0.0      2-9
# 1046      0.0  100-299

# %% [markdown]
# ## 4. Explorar categorías y ejes de análisis

# %% [markdown]
# Definimos una función de limpieza de nombres

# %%
import numpy as np
import re

def limpiar_nombre(nombre):
    if type(nombre) == float and np.isnan(nombre):
        return "SIN NOMBRE"
    nombre = nombre.lower()\
                .replace("á", "a")\
                .replace("é", "e")\
                .replace("í", "i")\
                .replace("ó", "o")\
                .replace("ú", "u")\
                .replace("ñ", "n")
    nombre = re.sub("\/.*", "", nombre) # Quitar texto después de la diagonal
    nombre = re.sub("[^A-Za-z\s]*", "", nombre) # Quitar caracteres fuera de la A-Z y a-z
    nombre = re.sub("\s+", " ", nombre) # Quitar espacios repetidos
    return nombre.upper().strip() # Devuelve el nombre en mayúsculas y sin espacios finales

print("Se definió la función para limpiar nombres")
# Out:
# Se definió la función para limpiar nombres

# %% [markdown]
# Limpiamos la columna `LIDER` para su análisis

# %%
proyectos["LIDER"] = proyectos["LIDER"].map(limpiar_nombre)

lideres = proyectos["LIDER"].unique()
lideres.sort()

lideres
# Out:
# array(['ADALBERTO ZAMORA BORBOA', 'AGLAE CASTRO GARCIA', 'ALBA GUADALUPE',
#        'ALBA GUADALUPE QUINONEZ SAN JUAN', 'ALEJANDRA HERNANDEZ MEZA',
#        'ALEXIS VALENZUELA QUINTERO', 'ALFONSO CARRANZA BELTRAN',
#        'ALFREDO MONTES SOSA', 'ALMA PATRICIA GARCIA LEYVA',
#        'ALVARO LEVI MORGAN COTA', 'ANA ALICIA ACOSTA MERAZ',
#        'ANDREA ITZEL ESTUDILLO ARREDONDO', 'ANDREA ROMERO MENDEZ',
#        'ANDREA YAQUELIN RIVERA TORRES', 'ANGEL GABRIEL PULIDO BARRON',
#        'ANGELA MARIELA CARRERA PINO', 'ANSELMO VERDUGO GASTELUM',
#        'AOD JAUREGUI RUIZ', 'ARMANDO ALBERTO GUZMAN COTA',
#        'ARMANDO MEDINA CARDENAS', 'ASUCENA BOJORQUEZ GUTIERREZ',
#        'AURORA ROJO ZEPEDA', 'AZUCENA COTA PACHECO',
#        'BEATRIZ ELENA JACOBO RAYA', 'BEATRIZ REBECA ALVARADO LOPEZ',
#        'BERNARDO CARLOS BAEZ GONZALEZ', 'BETEL ANAHI LOPEZ MIRANDA',
#        'BRENDA CARELI RUELAS AGUIRRE', 'BRENDA DANIELA BORBOLLA RAMIREZ',
#        'CARLOS EDGAR LAFARGA TORRES', 'CARLOS GILBERTO BURGUENO GARCIA',
#        'CARLOS JESUS QUINTERO ANDRADE', 'CARMEN LUCIA VERDUGO MACIAS',
#        'CARMEN OROZCO IBARRIA', 'CASANDRA MONTOYA VALENZUELA',
#        'CELENE BERENICE SANTOS AGUILAR', 'CELENE JAZMIN RAMOS LOPEZ',
#        'CESAR RAUL MENDOZA URDIALES', 'CHRISTIAN HUMBERTO GALVEZ ISLAS',
#        'CHRISTIAN JESUS NIEBLAS CONTRERAS',
#        'CHRISTIAN MIGUEL LEYVA JIMENEZ', 'CINTHYA KARINA ZAZUETA HIGUERA',
#        'CITLALI AGUILAR LEMUS', 'CLAUDIA BATIZ BELTRAN',
#        'CLAUDIA LIZETH GARCIA CERVANTES', 'CLAUDIA ROCIO MADRID IBARRA',
#        'CRISTABEL SILVA BARRAZA', 'CRISTHIAN EDUARDO LOPEZ VALENZUELA',
#        'CRISTIAN MORENO PARRA', 'CRISTIAN VALENTINA AGUILAR PEREZ',
#        'CRUZ ERNESTO OSUNA GUERRERO', 'CRUZ MANUEL CASTRO ROCHIN',
#        'CYNTHIA VERDUGO DEPRAECT', 'DALIA GUADALUPE GOMEZ ALFARO',
#        'DANIEL CASTRO OLIVAS', 'DANIELA ARISBETH ORTIZ ESTUDILLO',
#        'DENISSE ISABEL ABITIA ACOSTA', 'DIANA LIZBETH MARTINEZ QUINONEZ',
#        'DORA IRMA GUZMAN FAVELA', 'DULCE KARELY RAMIREZ SANCHEZ',
#        'EDGAR EMIR LEZAMA LOPEZ', 'EDGAR MANJARREZ LOPEZ',
#        'EDGAR PAUL ANGULO ELIZALDE', 'EDGAR VAEL RICO VALLEJO',
#        'ELBA MARIANA HERNANDEZ PEREZ', 'ELEAZAR CASTRO SANCHEZ',
#        'ELLIOT GADIEL BARRON VALDEZ', 'ERICK NOE HIGUERA TINOCO',
#        'ERIK OMAR CARRILLO PORTILLO', 'ERIK ROSARIO ZAMORANO LOPEZ',
#        'ESTEBAN ALENDAR HERRERA', 'EVELYN KARINA DUARTE CABANILLAS',
#        'EVELYN NICTTE MARQUEZ QUINTERO',
#        'FAVIOLA BELINDA RIVERA MADRIGAL', 'FRANCISCA ROMERO VALVERDE',
#        'FRANCISCO JAVIER CRUZ YURIAR', 'FRANCISCO JAVIER ESCALANTE LUGO',
#        'FRANCISCO JAVIER MONTOYA CUADRAS', 'FRANCISCO JAVIER ROJAS FRIAS',
#        'FRANCISCO MANUEL VALENZUELA MORENO',
#        'GERMAN GUSTAVO AMILLANO GAMEZ', 'GILBERTO DANIEL AVILES MACEDO',
#        'GRACIELA NOEMI FELIX RIVERA', 'GUADALUPE SANCHEZ MEZA',
#        'GUILLERMO MENDOZA OLIVAS', 'HECTOR CORTES CALDERON',
#        'HERIBERTO ESTRADA RAMIREZ', 'HUGO GUADALUPE VAZQUEZ HERRERA',
#        'HUMBERTO SANCHEZ LOPEZ', 'INES JOSEFINA BORBOA VELEZ',
#        'IRENE YAHAIRA CORONA SAMANIEGO', 'IRIS MERCEDES ARIAS ZAZUETA',
#        'IRVINN STEVE AGUILAR GONZALES', 'ISABEL SERRANO RAMIREZ',
#        'ISAIAS DE JESUS CARRILLO ARREOLA', 'ISMAEL CARO RODRIGUEZ',
#        'ITZIA ROSENDA HEREDIA BOJORQUEZ', 'IVETH ALEJANDRA MEZA MORENO',
#        'JACOBO BUSTAMANTE LERMA', 'JAIRO ENRIQUE AGUILAR MAYTORENA',
#        'JAIRO IVAN PENA ESTUDILLO', 'JAVIER REYES HERRERA',
#        'JESSICA IRACEMA MARTINEZ AYON', 'JESUS ADAN GONZALEZ NIEBLA',
#        'JESUS ALBERTO ALVARADO VERDUGO', 'JESUS ALFONSO IMPERIAL OJEDA',
#        'JESUS ARELY GARCIA OBESO', 'JESUS EDGARDO AMADOR DERAZ',
#        'JESUS EDGARDO ZUNIGA LOPEZ',
#        'JESUS FRANCISCO GONZALEZ COVARRUBIAS',
#        'JESUS IVAN GASTELUM OJEDA', 'JESUS MANUEL MORENO FLORES',
#        'JESUS ROBERTO IBARRA BOJORQUEZ', 'JIBRAN MISAEL MERCADO OBESO',
#        'JOEL ARMANDO CRUZ GONZALEZ', 'JOEL CRUZ',
#        'JORGE ARMANDO RAMIREZ ACOSTA', 'JORGE ELIAS CRESPO GOMEZ',
#        'JORGE LUIS LEAL GUTIERREZ', 'JORGE RENE JUAREZ LAFARGA',
#        'JOSE AGUSTIN ZAZUETA RAMIREZ', 'JOSE ALBERTO ALAPIZCO FIGUEROA',
#        'JOSE ALFREDO LEY CARMONA', 'JOSE ANGEL CHAVEZ DOMINGUEZ',
#        'JOSE CARLOS LOPEZ GARCIA', 'JOSE EFRAIN GALAZ RAMOS',
#        'JOSE JESUS LOPEZ ARREDONDO', 'JOSE RAUL VERDUGO AHUMADA',
#        'JOVANNY CASTRO BURGOS', 'JUAN CARLOS ANGULO GARCIA',
#        'JUAN CARLOS HERMOSILLO RAMIREZ', 'JUAN CARLOS LOPEZ PALOS',
#        'JUAN CARLOS VALENZUELA DIAZ', 'JUAN EUSTIQUIO LOPEZ SALAS',
#        'JUAN MANUEL HERRAN CALDERON', 'JULIO CESAR LANDEY ZAMUDIO',
#        'JULIO CESAR OLEA DAMAS', 'JULIO ERNESTO AGUILAR TERRAZAS',
#        'KARELY JAZMIN CANEDO FELIX', 'KAREN BEATRIZ RUBIO ANGULO',
#        'KAREN DOLORES DURAN DEPRAECT', 'KAREN MARICELA LEYVA MILLAN',
#        'KARLA FABIOLA ESPINOZA ACEVES', 'KARLA VIRIDIANA PLATAS VARGAS',
#        'KATYA YAMILE GALAVIZ LOPEZ', 'KEILA ABIGAIL LARRETA CHAMORRO',
#        'KENIA JAZMIN LEYVA CAMACHO', 'KENIN URIAS ORONA',
#        'LEONZO ANTONIO LEON INZUNZA',
#        'LETICIA GUADALUPE RODRIGUEZ MARTINEZ',
#        'LILIANA BEATRIZ RIVAS CALDERON', 'LUIS ALBERTO NARANJO CASTANOS',
#        'LUIS ANGEL LEON BOJORQUEZ', 'LUIS ENRIQUE BARRON SANCHEZ',
#        'LUIS ENRIQUE CARDENAS HERNANDEZ', 'LUIS FERNANDO SANCHEZ ARREOLA',
#        'LUIS MANUEL ROMERO SALAZAR', 'LUIS MARIO CARDENAS FAVELA',
#        'LUIS ORLANDO RAMIREZ GARCIA', 'MANUEL ALEJANDRO RAMIREZ MORALES',
#        'MANUEL ENRIQUE TORRES LUGO', 'MANUEL RAMOS FIGUEROA',
#        'MARADY PACHECO QUINTERO', 'MARCELA IBETH FELIX DE LA O',
#        'MARCOS ANTONIO CUEVAS RODRIGUEZ',
#        'MARCOS WILLIAMS RICALDAY MORALES',
#        'MARIA ALEJANDRA CARDENAS LOPEZ PORTILLO',
#        'MARIA DEL SOCORRO AMADOR LOPEZ', 'MARIA ISABEL MEDINA SOTO',
#        'MARIA LIBRADA BON TORRES', 'MARIA LUISA AGUIAR GARCIA',
#        'MARIA OFELIA VEGA GARCIA', 'MARIAN CAROLINA GARCIA IBARRIA',
#        'MARINA JUDITH ALVAREZ GAXIOLA', 'MARIO ENRIQUE ZAVALA TOLANO',
#        'MARIO ROMERO FUENTES', 'MARTHA ISELA AGUIRRE LOPEZ',
#        'MARTIN EDUARDO MIRANDA MIRANDA', 'MARTIN HERIBERTO PARTIDA DURON',
#        'MARTIN NOE LOPEZ CAMPOS', 'MARTIN VALENZUELA OJEDA',
#        'MELISSA LOPEZ ARAGON', 'MILCA SARAI CARRISOZA ZAZUETA',
#        'MIRNA CELINA DOMINGUEZ GAMEZ', 'MITZEL JAZMIN RODRIGUEZ ROJAS',
#        'NAGIB ADALBERTO LAFARGA PICOS', 'NEREYDA PARRA LOAIZA',
#        'NIDIA CAROLINA SANTOS DIAZ', 'NIDIA MARITZA LOPEZ LOPEZ',
#        'NIDYA ESTEFANIA NAVIA NIEBLAS', 'NOE RIVAS LOPEZ',
#        'NOEL ELADIO BELTRAN DIAZ', 'NORMA LETICIA JIMENEZ GUADALUPE',
#        'OMAR ALEJANDRO RIVAS MURILLO', 'OMAR SOTO ALVAREZ',
#        'OSCAR ARMENTA OBESO', 'OSCAR MARRUJO LEON',
#        'OSVALDO GUADALUPE LOPEZ PARRA', 'OSWALDO MICHEL PEREZ',
#        'PAUL IVAN ONTIVEROS MARIN', 'PAUL IVAN QUINTERO VARELA',
#        'PEDRO ALEJANDRO AYALA ANISTRO', 'PRISCILA MASCARENO ROSAS',
#        'PRISCILLA MARGARITA SERRANO ACOSTA',
#        'RAFAEL ALBERTO HERNANDEZ JARAMILLO', 'RAFAEL DOMINGUEZ PEREZ',
#        'RAFAEL MENDOZA LIZARRAGA', 'RAUL HUMBERTO PIMENTEL VAZQUEZ',
#        'RAUL OSUNA GUTIERREZ', 'REYNA OLIVIA CONTRERAS GALVEZ',
#        'RIGOBERTO MONTOYA LEDEZMA', 'RIGOBERTO QUINTERO CARRANZA',
#        'RODOLFO JAVIER TORTOLERO VARELA', 'ROLANDO SAUCEDA MASCARENO',
#        'ROSA ATENEA BECERRA BURGOS', 'ROSARIO GUADALUPE GAXIOLA VALDEZ',
#        'ROSARIO GUADALUPE MEDINA ESPINOZA', 'RUBEN ANTONIO OJEDA MILAN',
#        'SALVADOR CARRILLO BELTRAN', 'SAUL IGNACIO RODELO ACOSTA',
#        'SERGIO DAVID MATTY GUZMAN', 'SERGIO ENRIQUE TIZNADO VELARDE',
#        'SHASHA LAURA FERNANDEZ NOLASCO', 'SHEILA RUBI LOPEZ DAGNINO',
#        'SIN LIDER ASIGNADO', 'SIN NOMBRE', 'SOFIA CARRAZCO VALENZUELA',
#        'TIRZO LAFARGA LUCERO', 'VALENTIN LOPEZ VALENZUELA',
#        'VICENTE VELARDE BAEZ', 'VICTOR HERNANDEZ LOPEZ',
#        'VICTOR IGNACIO PAEZ PARTIDA', 'VICTOR MANUEL VALENZUELA GUERRERO',
#        'VLADIMIR ESPINOZA OLIVA', 'VLADIMIR FELIX GALVEZ',
#        'WENDY LIZETH LUGO', 'WENDY VANESSA VELAZQUEZ ELENES',
#        'XITLALLYC ESCOBAR GONZALEZ', 'YADIRA MORENO ZAZUETA',
#        'YADIRA YUDITH MORALES ZAZUETA', 'YAGGER ALBERTO CORONA FELIX',
#        'YARELI LIZETH CALDERON CORONEL',
#        'YAZMIN DEL ROSARIO MARQUEZ BENITEZ',
#        'YOSINA MEREDITH LUGO GALAVIZ'], dtype=object)

# %% [markdown]
# ## 5. Conteos sobre ejes categóricos

# %% [markdown]
# Calculamos el dataset de los proyectos que ha tenido cada líder

# %%
proyectos["PROYECTO_COUNT"] = 1

#proyectos_lider = proyectos[ ["LIDER", "PROYECTO_COUNT"] ].groupby("LIDER").sum()
proyectos_lider = proyectos[ ["LIDER", "PROYECTO_COUNT"] ].groupby("LIDER", as_index=False).count()

proyectos_lider
# Out:
#                                   LIDER  PROYECTO_COUNT
# 0               ADALBERTO ZAMORA BORBOA              15
# 1                   AGLAE CASTRO GARCIA               1
# 2                        ALBA GUADALUPE               1
# 3      ALBA GUADALUPE QUINONEZ SAN JUAN              18
# 4              ALEJANDRA HERNANDEZ MEZA              11
# ..                                  ...             ...
# 239       YADIRA YUDITH MORALES ZAZUETA              26
# 240         YAGGER ALBERTO CORONA FELIX              13
# 241      YARELI LIZETH CALDERON CORONEL              21
# 242  YAZMIN DEL ROSARIO MARQUEZ BENITEZ              17
# 243        YOSINA MEREDITH LUGO GALAVIZ              28
#
# [244 rows x 2 columns]

# %% [markdown]
# Integramos el conteo al dataset de proyectos. Esto significa que los proyectos ahora sabrán cuántos proyectos tuvo el líder para cada uno de los proyectos.

# %%
proyectos.sample(3)
# Out:
#       ID_PROYECTO    EMPRESA  PETICION  PETICION_1   PET_EMPRESA
# 2954         2955  Bancoppel     871.1         871  871Bancoppel  \
# 116           117     México   13804.0       13804   13804México
# 1650         1651  Bancoppel     746.1         746  746Bancoppel
#
#                                                  NOMBRE  CFP  EFICIENCIA
# 2954                      Timestamps (Complementaria 7)   13    0.355932  \
# 116                        Sorteo Regreso a Clases 2016    8         NaN
# 1650  Enmascarado de datos en ventanilla y cancelaci...   45    1.400000
#
#             PDR  ESFUERZO_TOTAL_P  ...  PDR_M_1  PDR_M_2  PDR_L LEAD_TIME
# 2954  73.074615            1089.0  ...      NaN      NaN    NaN     276.0  \
# 116   54.187500             200.0  ...      NaN      NaN    NaN      29.0
# 1650  20.859111             962.0  ...      NaN      NaN    NaN      77.0
#
#      F1_GESTIONDELA_DEMANDA  F2_ELICITACION F3_CONTRUCCION F4_FINAL  TAMANO
# 2954                   73.0            29.0          110.0     62.0   10-29  \
# 116                     4.0             3.0           22.0      0.0     2-9
# 1650                   13.0             5.0           54.0      3.0   30-99
#
#       PROYECTO_COUNT
# 2954               1
# 116                1
# 1650               1
#
# [3 rows x 139 columns]

# %%
proyectos_lider["LIDER"]
# Out:
# 0                 ADALBERTO ZAMORA BORBOA
# 1                     AGLAE CASTRO GARCIA
# 2                          ALBA GUADALUPE
# 3        ALBA GUADALUPE QUINONEZ SAN JUAN
# 4                ALEJANDRA HERNANDEZ MEZA
#                       ...
# 239         YADIRA YUDITH MORALES ZAZUETA
# 240           YAGGER ALBERTO CORONA FELIX
# 241        YARELI LIZETH CALDERON CORONEL
# 242    YAZMIN DEL ROSARIO MARQUEZ BENITEZ
# 243          YOSINA MEREDITH LUGO GALAVIZ
# Name: LIDER, Length: 244, dtype: object

# %% [markdown]
# Ejemplo para saber cuántos proyectos tiene un líder.

# %%
proyectos_lider[ (proyectos_lider["LIDER"] == "PAUL IVAN ONTIVEROS MARIN") ]["PROYECTO_COUNT"].values[0]
# Out:
# 30

# %% [markdown]
# Calculamos los proyectos para cada líder de cada proyecto.

# %%
proyectos["PROYECTOS_LIDER"] = proyectos["LIDER"].map(lambda nombre: proyectos_lider[ (proyectos_lider["LIDER"] == nombre) ]["PROYECTO_COUNT"].values[0])

proyectos.sample(5)[ ["ID_PROYECTO", "EMPRESA", "LIDER", "PROYECTOS_LIDER", "EFICIENCIA"] ]
# Out:
#       ID_PROYECTO    EMPRESA                      LIDER  PROYECTOS_LIDER
# 1581         1582  Argentina  VALENTIN LOPEZ VALENZUELA               12  \
# 137           138     México       MARIO ROMERO FUENTES               12
# 2049         2050     México    ADALBERTO ZAMORA BORBOA               15
# 604           605  Bancoppel  RUBEN ANTONIO OJEDA MILAN               45
# 399           400  Bancoppel                 SIN NOMBRE              204
#
#       EFICIENCIA
# 1581    0.579843
# 137          NaN
# 2049    1.375968
# 604          NaN
# 399          NaN

# %% [markdown]
# ## 6. Analizar por afinidad la siguiente hipótesis
#
#     SI EL LIDER TIENE MÁS DE LA MEDIA DE PROYECTOS, ENTONCES LA EFICIENCIA SERÁ MAYOR A LA MEDIA DE EFICIENCIAS
#
# Si el líder no tuviera más de la media de proyector (12 proyectos), entonces sabríamos bajo cierta confianza (por calcular), que el proyecto no será superior a la eficiencia promedio.

# %%
proyectos_lider["PROYECTO_COUNT"].mean()
# Out:
# 12.110655737704919

# %%
dataset = proyectos[ ["ID_PROYECTO", "LIDER", "PROYECTOS_LIDER", "EFICIENCIA"] ]

dataset = dataset[ (dataset["LIDER"] != "SIN NOMBRE") ]
dataset = dataset.dropna()

dataset.sample(5)
# Out:
#       ID_PROYECTO                                 LIDER  PROYECTOS_LIDER
# 2715         2716             JUAN CARLOS ANGULO GARCIA               24  \
# 1314         1315               CRISTABEL SILVA BARRAZA               27
# 2404         2405  LETICIA GUADALUPE RODRIGUEZ MARTINEZ                3
# 1650         1651           IRIS MERCEDES ARIAS ZAZUETA                8
# 1711         1712             JUAN CARLOS ANGULO GARCIA               24
#
#       EFICIENCIA
# 2715    0.828571
# 1314    1.400000
# 2404    0.518248
# 1650    1.400000
# 1711    1.400000

# %%
corr_proyectos_eficiencia = dataset["PROYECTOS_LIDER"].corr(dataset["EFICIENCIA"])

print("Correlación: {:.4f}".format(corr_proyectos_eficiencia))
# Out:
# Correlación: 0.1575

# %%
total = dataset[ (dataset["PROYECTOS_LIDER"] > proyectos_lider["PROYECTO_COUNT"].mean()) ].count().values[0]       # El total de proyectos donde el líder tuvo más del promedio

print("Total de proyectos donde el líder tiene más proyecto que la media: {}".format(total))
# Out:
# Total de proyectos donde el líder tiene más proyecto que la media: 1135

# %%
support = dataset[ (dataset["PROYECTOS_LIDER"] > proyectos_lider["PROYECTO_COUNT"].mean()) & (dataset["EFICIENCIA"] > dataset["EFICIENCIA"].mean()) ].count().values[0]

print("Soporte de proyectos donde el líder tiene más proyecto que la media y la eficiencia es mayor a la media: {}".format(support))
# Out:
# Soporte de proyectos donde el líder tiene más proyecto que la media y la eficiencia es mayor a la media: 521

# %%
confidence = 100 * support / total

print("Podemos afirmar con un {:.1f}% de confianza que si un líder tiene más de la media de proyectos ({:.0f}), entonces la eficiencia será mayor a la media ({:.4f})".format(confidence, proyectos_lider["PROYECTO_COUNT"].mean(), dataset["EFICIENCIA"].mean()))
# Out:
# Podemos afirmar con un 45.9% de confianza que si un líder tiene más de la media de proyectos (12), entonces la eficiencia será mayor a la media (0.8177)
